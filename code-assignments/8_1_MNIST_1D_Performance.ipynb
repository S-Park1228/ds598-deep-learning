# %% [markdown]
# While editing this notebook, don't change cell types as that confuses the autograder.
#
# Before you turn this notebook in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name below:

# %%
NAME = "Sungjoon Park"

# %% [markdown]
# _Understanding Deep Learning_

# %% [markdown]
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/DL4DS/sp2024_notebooks/blob/main/release/nbs08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 8.1: MNIST_1D_Performance
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a.
# It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Adapted from notebooks at https://github.com/udlbook/udlbook.

# %%
# Clone the mnist1d repository if it doesn't exist
import os

if not os.path.exists('mnist1d'):
    # !git clone https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
from torchinfo import summary

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions

# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
# model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o))

# YOUR CODE HERE
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
)
# raise NotImplementedError()

def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
#   print("Initializing layer")

    # YOUR CODE HERE
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_normal_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)
model.apply(weights_init)
#   raise NotImplementedError()

# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
print(summary(model, input_size=(1, D_i), device='cpu'))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [1, 10]                   --
# ├─Linear: 1-1                            [1, 100]                  4,100
# ├─ReLU: 1-2                              [1, 100]                  --
# ├─Linear: 1-3                            [1, 100]                  10,100
# ├─ReLU: 1-4                              [1, 100]                  --
# ├─Linear: 1-5                            [1, 10]                   1,010
# ==========================================================================================
# Total params: 15,210
# Trainable params: 15,210
# Non-trainable params: 0
# Total mult-adds (M): 0.02
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.06
# ==========================================================================================

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()

# construct SGD optimizer and initialize learning rate and momentum
# original lr = 0.05, momentum = 0.9
optimizer = torch.optim.SGD(model.parameters(), lr = 0.1)

# object that decreases learning rate by half every 10 epochs
# scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

# create 100 dummy data points and store in data loader class
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100 # was 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  # scheduler.step()
# Out:
# Epoch     0, train loss 1.816828, train error 70.88,  test loss 1.886057, test error 73.30
# Epoch     1, train loss 1.676263, train error 66.90,  test loss 1.760810, test error 69.00
# Epoch     2, train loss 1.541954, train error 59.65,  test loss 1.668718, test error 65.70
# Epoch     3, train loss 1.518341, train error 59.53,  test loss 1.641170, test error 65.20
# Epoch     4, train loss 1.413974, train error 54.33,  test loss 1.565733, test error 62.40
# Epoch     5, train loss 1.350698, train error 50.72,  test loss 1.528471, test error 61.90
# Epoch     6, train loss 1.274155, train error 45.92,  test loss 1.465488, test error 58.40
# Epoch     7, train loss 1.249527, train error 45.40,  test loss 1.454230, test error 57.90
# Epoch     8, train loss 1.173217, train error 41.60,  test loss 1.399081, test error 54.70
# Epoch     9, train loss 1.151915, train error 42.60,  test loss 1.392397, test error 54.80
# Epoch    10, train loss 1.115356, train error 39.65,  test loss 1.360266, test error 52.30
# Epoch    11, train loss 1.052334, train error 36.90,  test loss 1.316498, test error 51.80
# Epoch    12, train loss 1.032467, train error 36.70,  test loss 1.308424, test error 50.70
# Epoch    13, train loss 0.974423, train error 32.90,  test loss 1.266869, test error 48.10
# Epoch    14, train loss 0.963849, train error 34.07,  test loss 1.284732, test error 49.60
# Epoch    15, train loss 0.933682, train error 32.62,  test loss 1.256581, test error 48.30
# Epoch    16, train loss 0.888176, train error 30.32,  test loss 1.232005, test error 47.90
# Epoch    17, train loss 0.868513, train error 29.30,  test loss 1.215689, test error 46.90
# Epoch    18, train loss 0.835368, train error 27.95,  test loss 1.195942, test error 46.10
# Epoch    19, train loss 0.811196, train error 26.40,  test loss 1.195657, test error 46.10
# Epoch    20, train loss 0.802928, train error 27.88,  test loss 1.189862, test error 44.20
# Epoch    21, train loss 0.778153, train error 26.43,  test loss 1.191327, test error 44.70
# Epoch    22, train loss 0.746890, train error 24.85,  test loss 1.168560, test error 44.00
# Epoch    23, train loss 0.728958, train error 24.95,  test loss 1.192476, test error 45.80
# Epoch    24, train loss 0.707496, train error 23.88,  test loss 1.175422, test error 43.80
# Epoch    25, train loss 0.667651, train error 21.65,  test loss 1.157505, test error 43.20
# Epoch    26, train loss 0.651498, train error 21.15,  test loss 1.143061, test error 41.70
# Epoch    27, train loss 0.626464, train error 20.35,  test loss 1.133109, test error 42.90
# Epoch    28, train loss 0.611786, train error 19.05,  test loss 1.146671, test error 42.60
# Epoch    29, train loss 0.606137, train error 19.70,  test loss 1.154347, test error 40.90
# Epoch    30, train loss 0.566067, train error 17.47,  test loss 1.122312, test error 41.10
# Epoch    31, train loss 0.557869, train error 17.10,  test loss 1.128454, test error 40.40
# Epoch    32, train loss 0.538764, train error 16.97,  test loss 1.147965, test error 42.30
# Epoch    33, train loss 0.518351, train error 15.95,  test loss 1.130438, test error 40.30
# Epoch    34, train loss 0.500355, train error 15.07,  test loss 1.137756, test error 41.20
# Epoch    35, train loss 0.484507, train error 14.28,  test loss 1.125844, test error 39.90
# Epoch    36, train loss 0.474404, train error 14.68,  test loss 1.133211, test error 40.90
# Epoch    37, train loss 0.473925, train error 14.35,  test loss 1.147063, test error 40.50
# Epoch    38, train loss 0.445504, train error 12.85,  test loss 1.140401, test error 41.10
# Epoch    39, train loss 0.432304, train error 12.47,  test loss 1.153882, test error 40.20
# Epoch    40, train loss 0.407000, train error 11.22,  test loss 1.159468, test error 41.30
# Epoch    41, train loss 0.403571, train error 12.07,  test loss 1.143407, test error 40.10
# Epoch    42, train loss 0.381443, train error 9.45,  test loss 1.152227, test error 39.10
# Epoch    43, train loss 0.400106, train error 11.95,  test loss 1.179887, test error 39.30
# Epoch    44, train loss 0.364407, train error 10.15,  test loss 1.175487, test error 39.50
# Epoch    45, train loss 0.354882, train error 9.15,  test loss 1.179030, test error 40.20
# Epoch    46, train loss 0.350573, train error 9.28,  test loss 1.203505, test error 40.70
# Epoch    47, train loss 0.320093, train error 7.97,  test loss 1.180341, test error 38.50
# Epoch    48, train loss 0.309171, train error 7.70,  test loss 1.215735, test error 39.10
# Epoch    49, train loss 0.315587, train error 8.38,  test loss 1.219722, test error 39.90
# Epoch    50, train loss 0.285608, train error 6.45,  test loss 1.196660, test error 40.00
# Epoch    51, train loss 0.290024, train error 7.35,  test loss 1.244477, test error 40.10
# Epoch    52, train loss 0.262186, train error 5.38,  test loss 1.222955, test error 39.00
# Epoch    53, train loss 0.258398, train error 5.70,  test loss 1.218083, test error 39.10
# Epoch    54, train loss 0.246670, train error 5.30,  test loss 1.218376, test error 38.80
# Epoch    55, train loss 0.224999, train error 3.78,  test loss 1.196427, test error 38.10
# Epoch    56, train loss 0.224430, train error 4.22,  test loss 1.229782, test error 39.00
# Epoch    57, train loss 0.215478, train error 4.22,  test loss 1.258625, test error 39.60
# Epoch    58, train loss 0.210832, train error 3.68,  test loss 1.259399, test error 39.30
# Epoch    59, train loss 0.201858, train error 3.53,  test loss 1.295390, test error 40.30
# Epoch    60, train loss 0.194188, train error 3.05,  test loss 1.309165, test error 40.20
# Epoch    61, train loss 0.185411, train error 3.10,  test loss 1.294310, test error 40.70
# Epoch    62, train loss 0.175059, train error 2.43,  test loss 1.284816, test error 41.00
# Epoch    63, train loss 0.171200, train error 2.65,  test loss 1.277897, test error 39.40
# Epoch    64, train loss 0.170087, train error 3.05,  test loss 1.299726, test error 39.70
# Epoch    65, train loss 0.152988, train error 2.20,  test loss 1.296330, test error 40.70
# Epoch    66, train loss 0.177428, train error 4.22,  test loss 1.362784, test error 40.60
# Epoch    67, train loss 0.156138, train error 2.93,  test loss 1.350695, test error 41.00
# Epoch    68, train loss 0.158115, train error 3.00,  test loss 1.368180, test error 40.70
# Epoch    69, train loss 0.133649, train error 1.60,  test loss 1.368220, test error 39.80
# Epoch    70, train loss 0.127195, train error 1.80,  test loss 1.354920, test error 39.70
# Epoch    71, train loss 0.132253, train error 1.82,  test loss 1.410716, test error 40.90
# Epoch    72, train loss 0.113263, train error 0.95,  test loss 1.362735, test error 39.70
# Epoch    73, train loss 0.112549, train error 1.07,  test loss 1.398676, test error 39.20
# Epoch    74, train loss 0.106541, train error 0.72,  test loss 1.370609, test error 39.30
# Epoch    75, train loss 0.108978, train error 0.95,  test loss 1.438003, test error 40.10
# Epoch    76, train loss 0.095619, train error 0.40,  test loss 1.423213, test error 39.50
# Epoch    77, train loss 0.101168, train error 0.85,  test loss 1.415203, test error 40.40
# Epoch    78, train loss 0.097229, train error 0.53,  test loss 1.451793, test error 40.40
# Epoch    79, train loss 0.084628, train error 0.25,  test loss 1.446008, test error 39.60
# Epoch    80, train loss 0.077327, train error 0.10,  test loss 1.445055, test error 39.10
# Epoch    81, train loss 0.080018, train error 0.32,  test loss 1.434715, test error 38.50
# Epoch    82, train loss 0.079973, train error 0.45,  test loss 1.447904, test error 39.20
# Epoch    83, train loss 0.073007, train error 0.18,  test loss 1.472456, test error 39.20
# Epoch    84, train loss 0.065985, train error 0.05,  test loss 1.477764, test error 39.60
# Epoch    85, train loss 0.072177, train error 0.25,  test loss 1.503999, test error 39.30
# Epoch    86, train loss 0.063509, train error 0.05,  test loss 1.477214, test error 38.40
# Epoch    87, train loss 0.060495, train error 0.07,  test loss 1.502702, test error 39.50
# Epoch    88, train loss 0.059713, train error 0.10,  test loss 1.488969, test error 39.10
# Epoch    89, train loss 0.059457, train error 0.05,  test loss 1.528766, test error 39.80
# Epoch    90, train loss 0.054686, train error 0.05,  test loss 1.533201, test error 39.60
# Epoch    91, train loss 0.052545, train error 0.03,  test loss 1.528104, test error 38.80
# Epoch    92, train loss 0.049719, train error 0.00,  test loss 1.543345, test error 38.90
# Epoch    93, train loss 0.057279, train error 0.30,  test loss 1.568937, test error 39.00
# Epoch    94, train loss 0.047435, train error 0.03,  test loss 1.541684, test error 39.30
# Epoch    95, train loss 0.046049, train error 0.00,  test loss 1.551710, test error 39.90
# Epoch    96, train loss 0.046133, train error 0.00,  test loss 1.574860, test error 39.40
# Epoch    97, train loss 0.042231, train error 0.03,  test loss 1.573282, test error 39.50
# Epoch    98, train loss 0.040513, train error 0.00,  test loss 1.570504, test error 38.70
# Epoch    99, train loss 0.039372, train error 0.00,  test loss 1.590883, test error 39.20

# %%
# Your trained model should satisfy these limits
# Do not modify this cell

assert losses_train[-1] < 0.05, "Loss on training set is too high"
assert errors_train[-1] < .01, "Error on training set is too high"

assert losses_test[-1] < 1.7, "Loss on test set is too high"
assert np.min(losses_test) < 1.3, "Minimum loss on test set is too high"

assert errors_test[-1] < 40, "Error on test set is too high"

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# Look at the difference between training and test, and observe what is happening to test loss as training proceeds.
#
# We'll also come back and compare this to the convolutional neural network later.
