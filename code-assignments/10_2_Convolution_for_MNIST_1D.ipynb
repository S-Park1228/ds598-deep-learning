# %% [markdown]
# While editing this notebook, don't change cell types as that confuses the autograder.
#
# Before you turn this notebook in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name below:

# %%
NAME = "Sungjoon Park"

# %% [markdown]
# _Understanding Deep Learning_

# %% [markdown]
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/DL4DS/sp2024_notebooks/blob/main/release/nbs10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 10.2: Convolution for MNIST-1D
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Adapted from notebooks at https://github.com/udlbook/udlbook.

# %%
# Clone the mnist1d repository if it doesn't exist
import os

if not os.path.exists('mnist1d'):
    # !git clone https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random
from torchinfo import summary

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# model = None

# YOUR CODE HERE
model = nn.Sequential(
    nn.Conv1d(1, 15, 3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Conv1d(15, 15, 3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Conv1d(15, 15, 3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(15*4, D_o)
)
# raise NotImplementedError()

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)

# %%
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# %%
print(len(data_loader))
print(len(x_train))
print(len(y_train))
print(len(x_val))
print(len(y_val))
# Out:
# 40
# 4000
# 4000
# 1000
# 1000

# %%
# Initialize model weights
model.apply(weights_init)
print(model)
summary(model, input_size=(100, 1, 40))
# Out:
# Sequential(
#   (0): Conv1d(1, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (1): ReLU()
#   (2): Conv1d(15, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (3): ReLU()
#   (4): Conv1d(15, 15, kernel_size=(3,), stride=(2,), padding=valid)
#   (5): ReLU()
#   (6): Flatten(start_dim=1, end_dim=-1)
#   (7): Linear(in_features=60, out_features=10, bias=True)
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [100, 10]                 --
# ├─Conv1d: 1-1                            [100, 15, 19]             60
# ├─ReLU: 1-2                              [100, 15, 19]             --
# ├─Conv1d: 1-3                            [100, 15, 9]              690
# ├─ReLU: 1-4                              [100, 15, 9]              --
# ├─Conv1d: 1-5                            [100, 15, 4]              690
# ├─ReLU: 1-6                              [100, 15, 4]              --
# ├─Flatten: 1-7                           [100, 60]                 --
# ├─Linear: 1-8                            [100, 10]                 610
# ==========================================================================================
# Total params: 2,050
# Trainable params: 2,050
# Non-trainable params: 0
# Total mult-adds (M): 1.07
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.39
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.42
# ==========================================================================================

# %%
# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.162344, train error 79.70,  val loss 2.157472, percent error 81.60
# Epoch     1, train loss 1.661186, train error 68.10,  val loss 1.681058, percent error 70.00
# Epoch     2, train loss 1.389674, train error 55.80,  val loss 1.410504, percent error 59.10
# Epoch     3, train loss 1.306270, train error 52.80,  val loss 1.326425, percent error 55.50
# Epoch     4, train loss 1.373128, train error 55.12,  val loss 1.393697, percent error 57.60
# Epoch     5, train loss 1.115238, train error 44.17,  val loss 1.132763, percent error 46.80
# Epoch     6, train loss 1.019165, train error 39.97,  val loss 1.034179, percent error 41.80
# Epoch     7, train loss 0.882912, train error 34.53,  val loss 0.939022, percent error 37.90
# Epoch     8, train loss 0.842557, train error 34.50,  val loss 0.913786, percent error 36.90
# Epoch     9, train loss 0.714963, train error 27.93,  val loss 0.781848, percent error 31.70
# Epoch    10, train loss 0.687077, train error 28.90,  val loss 0.756679, percent error 30.40
# Epoch    11, train loss 0.621349, train error 23.95,  val loss 0.684448, percent error 27.90
# Epoch    12, train loss 0.570737, train error 21.18,  val loss 0.652905, percent error 26.60
# Epoch    13, train loss 0.512293, train error 18.97,  val loss 0.581209, percent error 21.40
# Epoch    14, train loss 0.449909, train error 16.53,  val loss 0.547159, percent error 20.80
# Epoch    15, train loss 0.427177, train error 15.82,  val loss 0.531591, percent error 18.80
# Epoch    16, train loss 0.394433, train error 13.93,  val loss 0.512319, percent error 18.50
# Epoch    17, train loss 0.353621, train error 12.15,  val loss 0.471592, percent error 15.70
# Epoch    18, train loss 0.452602, train error 16.62,  val loss 0.564521, percent error 19.00
# Epoch    19, train loss 0.342659, train error 12.70,  val loss 0.476164, percent error 17.20
# Epoch    20, train loss 0.256042, train error 9.05,  val loss 0.399823, percent error 13.30
# Epoch    21, train loss 0.250848, train error 8.88,  val loss 0.408475, percent error 14.50
# Epoch    22, train loss 0.233481, train error 7.88,  val loss 0.396783, percent error 12.60
# Epoch    23, train loss 0.260895, train error 9.03,  val loss 0.426388, percent error 15.10
# Epoch    24, train loss 0.236055, train error 8.45,  val loss 0.425985, percent error 12.90
# Epoch    25, train loss 0.215254, train error 7.38,  val loss 0.399721, percent error 13.80
# Epoch    26, train loss 0.218464, train error 7.93,  val loss 0.409859, percent error 12.80
# Epoch    27, train loss 0.186203, train error 6.60,  val loss 0.391319, percent error 12.40
# Epoch    28, train loss 0.214192, train error 7.20,  val loss 0.395236, percent error 14.00
# Epoch    29, train loss 0.194094, train error 7.00,  val loss 0.370289, percent error 12.20
# Epoch    30, train loss 0.169081, train error 5.60,  val loss 0.387132, percent error 11.60
# Epoch    31, train loss 0.184502, train error 6.50,  val loss 0.390478, percent error 12.60
# Epoch    32, train loss 0.163834, train error 5.50,  val loss 0.388345, percent error 11.90
# Epoch    33, train loss 0.146603, train error 4.82,  val loss 0.372814, percent error 11.70
# Epoch    34, train loss 0.159279, train error 5.80,  val loss 0.399115, percent error 12.70
# Epoch    35, train loss 0.141805, train error 4.20,  val loss 0.352817, percent error 11.40
# Epoch    36, train loss 0.129419, train error 4.30,  val loss 0.380457, percent error 11.10
# Epoch    37, train loss 0.137223, train error 4.68,  val loss 0.355849, percent error 11.50
# Epoch    38, train loss 0.124976, train error 4.18,  val loss 0.361828, percent error 11.40
# Epoch    39, train loss 0.137473, train error 5.05,  val loss 0.412504, percent error 12.10
# Epoch    40, train loss 0.093246, train error 2.53,  val loss 0.345935, percent error 10.40
# Epoch    41, train loss 0.096047, train error 3.03,  val loss 0.363150, percent error 10.70
# Epoch    42, train loss 0.083227, train error 2.15,  val loss 0.346596, percent error 10.20
# Epoch    43, train loss 0.090103, train error 2.70,  val loss 0.364169, percent error 10.60
# Epoch    44, train loss 0.082441, train error 2.25,  val loss 0.344441, percent error 9.80
# Epoch    45, train loss 0.076800, train error 1.88,  val loss 0.351341, percent error 9.90
# Epoch    46, train loss 0.075247, train error 1.93,  val loss 0.351333, percent error 9.90
# Epoch    47, train loss 0.081121, train error 2.38,  val loss 0.362159, percent error 10.30
# Epoch    48, train loss 0.071064, train error 1.78,  val loss 0.344733, percent error 10.00
# Epoch    49, train loss 0.072916, train error 1.68,  val loss 0.351303, percent error 10.60
# Epoch    50, train loss 0.071982, train error 1.82,  val loss 0.346197, percent error 9.90
# Epoch    51, train loss 0.068406, train error 1.85,  val loss 0.368314, percent error 10.30
# Epoch    52, train loss 0.068266, train error 1.82,  val loss 0.355138, percent error 9.90
# Epoch    53, train loss 0.062569, train error 1.53,  val loss 0.357442, percent error 9.60
# Epoch    54, train loss 0.060885, train error 1.50,  val loss 0.364347, percent error 9.60
# Epoch    55, train loss 0.062124, train error 1.60,  val loss 0.356216, percent error 10.10
# Epoch    56, train loss 0.056773, train error 1.28,  val loss 0.368222, percent error 9.50
# Epoch    57, train loss 0.057310, train error 1.30,  val loss 0.369112, percent error 10.30
# Epoch    58, train loss 0.058641, train error 1.50,  val loss 0.361896, percent error 9.60
# Epoch    59, train loss 0.054228, train error 1.30,  val loss 0.361078, percent error 9.10
# Epoch    60, train loss 0.049736, train error 0.90,  val loss 0.368070, percent error 10.00
# Epoch    61, train loss 0.048973, train error 1.00,  val loss 0.365293, percent error 9.70
# Epoch    62, train loss 0.049111, train error 0.93,  val loss 0.357097, percent error 9.70
# Epoch    63, train loss 0.047357, train error 1.00,  val loss 0.370942, percent error 10.00
# Epoch    64, train loss 0.045925, train error 0.80,  val loss 0.369672, percent error 9.80
# Epoch    65, train loss 0.045906, train error 0.80,  val loss 0.365434, percent error 10.00
# Epoch    66, train loss 0.045558, train error 0.93,  val loss 0.375104, percent error 9.50
# Epoch    67, train loss 0.045332, train error 0.82,  val loss 0.368922, percent error 10.30
# Epoch    68, train loss 0.043613, train error 0.60,  val loss 0.378337, percent error 10.20
# Epoch    69, train loss 0.042645, train error 0.72,  val loss 0.370651, percent error 9.60
# Epoch    70, train loss 0.041782, train error 0.75,  val loss 0.373336, percent error 9.70
# Epoch    71, train loss 0.041480, train error 0.65,  val loss 0.373915, percent error 9.60
# Epoch    72, train loss 0.041097, train error 0.70,  val loss 0.374417, percent error 9.80
# Epoch    73, train loss 0.042460, train error 0.70,  val loss 0.374523, percent error 9.50
# Epoch    74, train loss 0.040826, train error 0.57,  val loss 0.374036, percent error 9.50
# Epoch    75, train loss 0.041757, train error 0.68,  val loss 0.378275, percent error 10.10
# Epoch    76, train loss 0.040724, train error 0.62,  val loss 0.378100, percent error 9.90
# Epoch    77, train loss 0.039880, train error 0.68,  val loss 0.376750, percent error 9.90
# Epoch    78, train loss 0.037735, train error 0.50,  val loss 0.378620, percent error 10.20
# Epoch    79, train loss 0.038825, train error 0.65,  val loss 0.389192, percent error 10.00
# Epoch    80, train loss 0.036600, train error 0.50,  val loss 0.376066, percent error 10.10
# Epoch    81, train loss 0.037038, train error 0.60,  val loss 0.378988, percent error 9.90
# Epoch    82, train loss 0.035845, train error 0.45,  val loss 0.382871, percent error 9.80
# Epoch    83, train loss 0.035698, train error 0.47,  val loss 0.383183, percent error 9.70
# Epoch    84, train loss 0.035932, train error 0.50,  val loss 0.380762, percent error 10.00
# Epoch    85, train loss 0.035504, train error 0.47,  val loss 0.386564, percent error 10.00
# Epoch    86, train loss 0.035313, train error 0.45,  val loss 0.380912, percent error 9.90
# Epoch    87, train loss 0.034663, train error 0.38,  val loss 0.384050, percent error 10.30
# Epoch    88, train loss 0.034848, train error 0.43,  val loss 0.380875, percent error 10.00
# Epoch    89, train loss 0.034321, train error 0.38,  val loss 0.389132, percent error 10.00
# Epoch    90, train loss 0.033752, train error 0.35,  val loss 0.385904, percent error 10.00
# Epoch    91, train loss 0.033764, train error 0.38,  val loss 0.383491, percent error 10.00
# Epoch    92, train loss 0.033357, train error 0.32,  val loss 0.386388, percent error 9.90
# Epoch    93, train loss 0.033453, train error 0.38,  val loss 0.387050, percent error 10.00
# Epoch    94, train loss 0.033037, train error 0.40,  val loss 0.385929, percent error 10.00
# Epoch    95, train loss 0.033041, train error 0.38,  val loss 0.388065, percent error 10.00
# Epoch    96, train loss 0.033407, train error 0.45,  val loss 0.397260, percent error 10.00
# Epoch    97, train loss 0.032359, train error 0.35,  val loss 0.388406, percent error 9.90
# Epoch    98, train loss 0.033253, train error 0.40,  val loss 0.387035, percent error 10.20
# Epoch    99, train loss 0.031902, train error 0.32,  val loss 0.390548, percent error 10.00

# %% [markdown]
# Compare the number of parameters from the model summary above and the test error
# with the fully connected model in 8_1_MNIST_1D_Performance.ipynb.
